# %%
from flask import Flask, render_template, request
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.metrics import AUC
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import pickle
import cv2
from PIL import Image, ImageChops, ImageEnhance
import os
import itertools
app = Flask(__name__)

dependencies = {
    'auc_roc': AUC
}

class_names = {
0: 'Tampered (Fake)',
1: 'Authentic (Real)',

}

model = load_model('casia.h5')
def convert_to_ela_image(path, quality):
    temp_filename = 'temp_file_name.jpg'
    ela_filename = 'temp_ela.png'
    
    image = Image.open(path).convert('RGB')
    image.save(temp_filename, 'JPEG', quality = quality)
    temp_image = Image.open(temp_filename)
    
    ela_image = ImageChops.difference(image, temp_image)
    
    extrema = ela_image.getextrema()
    max_diff = max([ex[1] for ex in extrema])
    if max_diff == 0:
        max_diff = 1
    scale = 255.0 / max_diff
    
    ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)
    
    return ela_image

image_size = (200, 200)

def prepare_image(image_path):
    return np.array(convert_to_ela_image(image_path, 90).resize(image_size)).flatten() / 255.0


 
@app.route("/")
@app.route("/first")
def first():
    return render_template('first.html')
    
@app.route("/login")
def login():
    return render_template('login.html')   
    
@app.route("/index", methods=['GET', 'POST'])
def index():
    return render_template("index.html")


@app.route("/submit", methods = ['GET', 'POST'])
def get_output():
    if request.method == 'POST':
        img = request.files['my_image']
        # model = request.form['model']
        # print(model)
        
        img_path = "static/tests/" + img.filename
        
        img.save(img_path)
        #plt.imshow(img)


        image = prepare_image(img_path)
        image = image.reshape(-1, 200, 200, 3)
        y_pred = model.predict(image) 
        y_pred_class = np.argmax(y_pred, axis = 1)[0]
        predict_result =  class_names[y_pred_class]
        #  print(f'Class: {class_names[y_pred_class]} Confidence: {np.amax(y_pred) * 100:0.2f}')
    return render_template("prediction.html", prediction = predict_result, img_path = img_path)

@app.route("/performance")
def performance():
    return render_template('performance.html')   

@app.route("/chart")
def chart():
    return render_template('chart.html')   
    
if __name__ =='__main__':
    #app.run(debug = True)
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/css/styles.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:27] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:28] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:28] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:28] "GET /static/assets/img/liver11.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:28] "GET /static/assets/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?24e3eb84d0bcaf83d77f904c78ac1f47 HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:13:28] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/css/login.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/img/liver3.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?24e3eb84d0bcaf83d77f904c78ac1f47 HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:23:53] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/css/style.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:08] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/assets/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?24e3eb84d0bcaf83d77f904c78ac1f47 HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/assets/img/liver5.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/images/background1.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/images/background2.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [15/Mar/2024 11:24:09] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 1/1 [==============================] - 1s 1s/step
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/css/prediction.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/tests/Au_art_00020.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?24e3eb84d0bcaf83d77f904c78ac1f47 HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/img/liver.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:24:29] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 1/1 [==============================] - 0s 123ms/step
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/css/prediction.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/tests/Au_art_00020.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/img/liver.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/bootstrap-icons/fonts/bootstrap-icons.woff2?24e3eb84d0bcaf83d77f904c78ac1f47 HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:06] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 1/1 [==============================] - 0s 91ms/step
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "POST /submit HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/css/prediction.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/tests/Tp_D_CRN_M_O_nat10159_ani00001_12057.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:25] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /performance HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/css/performance.css HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/downloads.png HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/img/liver13.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:30] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /chart HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/aos/aos.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/bootstrap-icons/bootstrap-icons.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/css/chart.css HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/boxicons/css/boxicons.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/glightbox/css/glightbox.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/swiper/swiper-bundle.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/purecounter/purecounter_vanilla.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/download.png HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/ss.png HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/aos/aos.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/glightbox/js/glightbox.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/isotope-layout/isotope.pkgd.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/swiper/swiper-bundle.min.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/vendor/php-email-form/validate.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/js/main.js HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/img/footer-bg.jpg HTTP/1.1" 304 -
# 127.0.0.1 - - [15/Mar/2024 11:25:51] "GET /static/assets/img/liver8.jpg HTTP/1.1" 200 -
